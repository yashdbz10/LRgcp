# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
from sklearn.datasets import load_boston
boston = load_boston()
bos = pd.DataFrame(boston.data,columns = boston.feature_names)

# %%
bos.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
bos.shape
# Out:
# (506, 13)

# %%
bos.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
bos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %%
bos.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
bos["price"]=boston.target
bos.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
fig, axs = plt.subplots(1, 13, sharey=True)
bos.plot(kind='scatter', x='CRIM', y='price', ax=axs[0], figsize=(8, 8))
bos.plot(kind='scatter', x='ZN', y='price', ax=axs[1])
bos.plot(kind='scatter', x='INDUS', y='price', ax=axs[2])
bos.plot(kind='scatter', x='CHAS', y='price', ax=axs[3])
bos.plot(kind='scatter', x='NOX', y='price', ax=axs[4])
bos.plot(kind='scatter', x='RM', y='price', ax=axs[5])
bos.plot(kind='scatter', x='AGE', y='price', ax=axs[6])
bos.plot(kind='scatter', x='DIS', y='price', ax=axs[7])
bos.plot(kind='scatter', x='RAD', y='price', ax=axs[8])
bos.plot(kind='scatter', x='TAX', y='price', ax=axs[9])
bos.plot(kind='scatter', x='PTRATIO', y='price', ax=axs[10])
bos.plot(kind='scatter', x='B', y='price', ax=axs[11])
bos.plot(kind='scatter', x='LSTAT', y='price', ax=axs[12])

# %%
bos.plot.hist()

# %%
sns.distplot(bos)

# %%
bos.describe(include='all')
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1
for column in bos:
    if plotnumber<=12:
        ax = plt.subplot(4,3,plotnumber)
        sns.distplot(bos[column], kde_kws = {'bw' : 1.5})
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
bos['CRIM'] = bos['CRIM'].mean()
bos['ZN'] = bos['ZN'].mode()
bos['INDUS']  =bos['INDUS'].mean()
bos['CHAS'] = bos['CHAS'].mean()
bos['NOX'] = bos['NOX'].mean()
bos['RM']  =bos['INDUS'].mean()
bos['AGE'] = bos['AGE'].mean()
bos['DIS'] = bos['DIS'].mean()
bos['RAD']  =bos['RAD'].mode()
bos['TAX'] = bos['TAX'].mean()
bos['PTRATIO'] = bos['PTRATIO'].mean()
bos['B']  =bos['B'].mean()
bos['LSTAT']  =bos['LSTAT'].mean()

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1
for column in bos:
    if plotnumber<=12:
        ax = plt.subplot(4,3,plotnumber)
        sns.distplot(bos[column], kde_kws = {'bw' : 1.5})
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
bos.isnull().sum()
# Out:
# CRIM         0
# ZN         505
# INDUS        0
# CHAS         0
# NOX          0
# RM           0
# AGE          0
# DIS          0
# RAD        505
# TAX          0
# PTRATIO      0
# B            0
# LSTAT        0
# price        0
# dtype: int64

# %%
bos['ZN'].fillna(bos.ZN.median(),inplace=True)
bos['RAD'].fillna(bos.RAD.median(),inplace=True)

# %%
X=bos.drop(columns = 'price')
y=bos['price']

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X, y)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
print(lm.coef_)
# Out:
# -7.781110264218632e+29
# [ 5.02183785e+25  5.13248592e+11  0.00000000e+00  1.54313262e+24
#   0.00000000e+00  0.00000000e+00  3.16033560e+27  9.87604876e+25
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  1.57591479e+27
#  -9.90217000e+25]

# %%
plt.figure(figsize=(20,30), facecolor='white')
plotnumber = 1

for column in X:
    if plotnumber<=12 :
        ax = plt.subplot(4,3,plotnumber)
        plt.scatter(X[column],y)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('price',fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model  import Ridge,Lasso,RidgeCV, LassoCV, ElasticNet, ElasticNetCV, LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# %%
scaler =StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
x_train,x_test,y_train,y_test = train_test_split(X_scaled,y,test_size = 0.25,random_state=355)
y_train
# Out:
# 227    31.6
# 382    11.3
# 23     14.5
# 348    24.5
# 157    41.3
#        ...
# 291    37.3
# 501    22.4
# 346    17.2
# 130    19.2
# 254    21.9
# Name: price, Length: 379, dtype: float64

# %%
regression = LinearRegression()

regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
filename = 'boston_final.pickle'
pickle.dump(regression, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))
a=loaded_model.predict(scaler.transform([[200,100,50,20,5,10,11,15,5,1,40,55,13]]))
a
# Out:
# array([22.44907652])

# %%
regression.score(x_train,y_train)
# Out:
# 0.0

# %%
def adj_r2(x,y):
    r2 = regression.score(x,y)
    n = x.shape[0]
    p = x.shape[1]
    adjusted_r2 = 1-(1-r2)*(n-1)/(n-p-1)
    return adjusted_r2

# %%
adj_r2(x_train,y_train)
# Out:
# -0.03561643835616435

# %%
regression.score(x_test,y_test)
# Out:
# -0.0012449287234108652

# %%
adj_r2(x_test,y_test)
# Out:
# -0.11643239839955544

# %%
lasscv = LassoCV(alphas = None,cv = 5, max_iter = 10000, normalize = True)
lasscv.fit(x_train, y_train)
# Out:
# LassoCV(cv=5, max_iter=10000, normalize=True)

# %%
alpha = lasscv.alpha_
alpha
# Out:
# 1e-15

# %%
lasso_reg = Lasso(alpha)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=1e-15)

# %%
lasso_reg.score(x_test, y_test)
# Out:
# -0.0012449287234108652

# %%
alphas = np.random.uniform(low=0, high=10, size=(50,))
ridgecv = RidgeCV(alphas = alphas,cv=5,normalize = True)
ridgecv.fit(x_train, y_train)
# Out:
# RidgeCV(alphas=array([1.98363645, 5.69816187, 3.59935935, 2.85312474, 0.40043114,
#        8.73406861, 3.65208541, 9.98206919, 7.16787957, 8.01279408,
#        3.32040533, 7.15784104, 0.70872073, 6.05573795, 4.35814294,
#        7.02117703, 0.29314094, 4.20017694, 3.11118081, 7.15563295,
#        8.10432962, 5.50565897, 1.744921  , 7.67511004, 1.16112272,
#        3.44365725, 4.4794383 , 9.35233587, 0.34763858, 6.41619256,
#        9.31347661, 2.81147242, 8.94030915, 2.84193659, 3.25481953,
#        5.37346282, 7.20455126, 0.81424437, 7.49076544, 9.60467189,
#        1.57325954, 2.55323453, 5.66158084, 5.3511995 , 4.46968098,
#        7.19672017, 7.02318494, 5.04583464, 7.50947664, 1.11995384]),
#         cv=5, normalize=True)

# %%
ridgecv.alpha_
# Out:
# 1.9836364548333574

# %%
ridge_model = Ridge(alpha=ridgecv.alpha_)
ridge_model.fit(x_train, y_train)
# Out:
# Ridge(alpha=1.9836364548333574)

# %%
ridge_model.score(x_test, y_test)
# Out:
# -0.0012449287234108652

# %%
elasticCV = ElasticNetCV(alphas = None, cv =5)

elasticCV.fit(x_train, y_train)
# Out:
# ElasticNetCV(cv=5)

# %%
elasticCV.alpha_
# Out:
# 1e-15

# %%
elasticCV.l1_ratio
# Out:
# 0.5

# %%
elasticnet_reg = ElasticNet(alpha = elasticCV.alpha_,l1_ratio=0.5)
elasticnet_reg.fit(x_train, y_train)
# Out:
# ElasticNet(alpha=1e-15)

# %%
elasticnet_reg.score(x_test, y_test)
# Out:
# -0.0012449287234108652

# %%
prediction_lasso=lasso_reg.predict(x_test)
prediction_ridge=ridge_model.predict(x_test)
prediction_elastic=elasticnet_reg.predict(x_test)

# %%
sns.distplot(y_test-prediction_lasso)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.distplot(y_test-prediction_ridge)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.distplot(y_test-prediction_elastic)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>
